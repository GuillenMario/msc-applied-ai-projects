# %% [markdown]
# ## **Master in Applied Artificial Intelligence**
# ### **Course: Artificial Intelligence and Automatic Learning**
# ### Prof. Iván Olmos
# #### Tecnológico de Monterrey
#
# ### **Project: Reading, writing, Big Data Pyspark files**
# ##### **Name and enrollment numbers of the team members:**
# * Victoria Melgarejo Cabrera - A01795030
# * Héctor Alejandro Alvarez Rosas - A01796262
# * Andrea Xcaret Gomez Alfaro - A01796384
# * Mario Guillen de la Torre - A01796701

# %% [markdown]
# ---
# #### **Activity Description:**
# Identify a Big Data database for the application of the concepts learned in the course, starting with the basic manipulation of reading and writing files with PysPark.
#
# ---

# %%
# Pyspark installation in Colab
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in c:\users\mario\anaconda3\envs\env_pyspark\lib\site-packages (3.5.4)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\mario\anaconda3\envs\env_pyspark\lib\site-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# ### **Import of libraries**

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, isnan, when, count, percentile_approx
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### **Creation of the Spark session**

# %%
spark = SparkSession.builder \
    .appName("ChicagoTaxyTripsAnalysis") \
     .config("spark.executor.memory", "4g") \
    .config("spark.driver.memory", "4g") \
    .config("spark.python.worker.timeout", "600") \
    .config("spark.python.worker.retries", "3") \
    .getOrCreate()

# %% [markdown]
# ### **Loading of datasets**

# %%
filename = "Taxi_Trips__2024-__20250426.csv"

# Local route where you want to save the file
local_path = filename

# CSV file load
dftaxytrips = spark.read.csv(local_path, header=True, inferSchema=True)

# %%
print("Number of records:", dftaxytrips.count())
print("Number of columns:", len(dftaxytrips.columns))
# Out:
# Number of records: 7917844
# Number of columns: 23

# %% [markdown]
# ### **Data exploration**

# %%
# DATASET structure
dftaxytrips.printSchema()
# Out:
# root
#  |-- Trip ID: string (nullable = true)
#  |-- Taxi ID: string (nullable = true)
#  |-- Trip Start Timestamp: string (nullable = true)
#  |-- Trip End Timestamp: string (nullable = true)
#  |-- Trip Seconds: integer (nullable = true)
#  |-- Trip Miles: double (nullable = true)
#  |-- Pickup Census Tract: long (nullable = true)
#  |-- Dropoff Census Tract: long (nullable = true)
#  |-- Pickup Community Area: integer (nullable = true)
#  |-- Dropoff Community Area: integer (nullable = true)
#  |-- Fare: double (nullable = true)
#  |-- Tips: double (nullable = true)
#  |-- Tolls: double (nullable = true)
#  |-- Extras: double (nullable = true)
#  |-- Trip Total: double (nullable = true)
#  |-- Payment Type: string (nullable = true)
#  |-- Company: string (nullable = true)
#  |-- Pickup Centroid Latitude: double (nullable = true)
#  |-- Pickup Centroid Longitude: double (nullable = true)
#  |-- Pickup Centroid Location: string (nullable = true)
#  |-- Dropoff Centroid Latitude: double (nullable = true)
#  |-- Dropoff Centroid Longitude: double (nullable = true)
#  |-- Dropoff Centroid  Location: string (nullable = true)

# %%
# First rows
dftaxytrips.limit(5).toPandas()
# Out:
#                                     Trip ID  \
# 0  0000184e7cd53cee95af32eba49c44e4d20adcd8
# 1  000072ee076c9038868e239ca54185eb43959db0
# 2  000074019d598c2b1d6e77fbae79e40b0461a2fc
# 3  00007572c5f92e2ff067e6f838a5ad74e83665d3
# 4  00007c3e7546e2c7d15168586943a9c22c3856cf
#
#                                              Taxi ID    Trip Start Timestamp  \
# 0  f538e6b729d1aaad4230e9dcd9dc2fd9a168826ddadbd6...  01/19/2024 05:00:00 PM
# 1  e51e2c30caec952b40b8329a68b498e18ce8a1f40fa75c...  01/28/2024 02:30:00 PM
# 2  aeb280ef3be3e27e081eb6e76027615b0d40925b84d3eb...  01/05/2024 09:00:00 AM
# 3  7d21c2ca227db8f27dda96612bfe5520ab408fa9a462c8...  01/22/2024 08:45:00 AM
# 4  8ef1056519939d511d24008e394f83e925d2539d668a00...  01/18/2024 07:15:00 PM
#
#        Trip End Timestamp  Trip Seconds  Trip Miles  Pickup Census Tract  \
# 0  01/19/2024 06:00:00 PM          4051       17.12         1.703198e+10
# 1  01/28/2024 03:00:00 PM          1749       12.70                  NaN
# 2  01/05/2024 09:00:00 AM           517        3.39                  NaN
# 3  01/22/2024 09:30:00 AM          2050       15.06                  NaN
# 4  01/18/2024 07:30:00 PM          1004        1.18         1.703184e+10
#
#    Dropoff Census Tract  Pickup Community Area  Dropoff Community Area  ...  \
# 0          1.703132e+10                     76                    32.0  ...
# 1                   NaN                      6                     NaN  ...
# 2                   NaN                      6                     8.0  ...
# 3                   NaN                     76                     NaN  ...
# 4          1.703184e+10                     32                    32.0  ...
#
#    Extras  Trip Total  Payment Type                       Company  \
# 0     4.0       60.00   Credit Card                     Flash Cab
# 1     0.0       33.75          Cash                     Flash Cab
# 2     1.0       14.69        Mobile  Taxicab Insurance Agency Llc
# 3     5.5       56.56   Credit Card                    Globe Taxi
# 4     0.0       19.66        Mobile                   5 Star Taxi
#
#    Pickup Centroid Latitude Pickup Centroid Longitude  \
# 0                 41.979071                -87.903040
# 1                 41.944227                -87.655998
# 2                 41.944227                -87.655998
# 3                 41.980264                -87.913625
# 4                 41.880994                -87.632746
#
#                Pickup Centroid Location  Dropoff Centroid Latitude  \
# 0  POINT (-87.9030396611 41.9790708201)                  41.884987
# 1  POINT (-87.6559981815 41.9442266014)                        NaN
# 2  POINT (-87.6559981815 41.9442266014)                  41.899602
# 3   POINT (-87.913624596 41.9802643146)                        NaN
# 4  POINT (-87.6327464887 41.8809944707)                  41.880994
#
#    Dropoff Centroid Longitude            Dropoff Centroid  Location
# 0                  -87.620993  POINT (-87.6209929134 41.8849871918)
# 1                         NaN                                  None
# 2                  -87.633308   POINT (-87.6333080367 41.899602111)
# 3                         NaN                                  None
# 4                  -87.632746  POINT (-87.6327464887 41.8809944707)
#
# [5 rows x 23 columns]

# %%
dftaxytrips.summary().toPandas().T
# Out:
#                                   0                      1  \
# summary                       count                   mean
# Trip ID                     7917844               Infinity
# Taxi ID                     7917844                   None
# Trip Start Timestamp        7917844                   None
# Trip End Timestamp          7917778                   None
# Trip Seconds                7916303     1254.9250153764958
# Trip Miles                  7917775      6.802327488467674
# Pickup Census Tract         3392900  1.7031508395342648E10
# Dropoff Census Tract        3281682   1.703141394138261E10
# Pickup Community Area       7691067      36.09328575605959
# Dropoff Community Area      7174891     26.293705646538744
# Fare                        7897269      22.89300292290886
# Tips                        7897269     2.9030046741474513
# Tolls                       7897269   0.029434495646532992
# Extras                      7897269     2.1529685008830275
# Trip Total                  7897269     28.182303074643663
# Payment Type                7917844                   None
# Company                     7917844                   None
# Pickup Centroid Latitude    7695376     41.901399650735996
# Pickup Centroid Longitude   7695376      -87.7019076253514
# Pickup Centroid Location    7695376                   None
# Dropoff Centroid Latitude   7220191       41.8921376218955
# Dropoff Centroid Longitude  7220191     -87.66080016228891
# Dropoff Centroid  Location  7220191                   None
#
#                                               2  \
# summary                                  stddev
# Trip ID                                    None
# Taxi ID                                    None
# Trip Start Timestamp                       None
# Trip End Timestamp                         None
# Trip Seconds                 1648.0977197601726
# Trip Miles                    7.957195844290252
# Pickup Census Tract           374237.3662004645
# Dropoff Census Tract          342509.8545557547
# Pickup Community Area        26.291497670579886
# Dropoff Community Area        20.81465342793271
# Fare                           33.2323786885119
# Tips                          4.284313925861233
# Tolls                        5.0707919401752175
# Extras                       10.395597618506331
# Trip Total                    38.30632012119162
# Payment Type                               None
# Company                                    None
# Pickup Centroid Latitude    0.06525246745369662
# Pickup Centroid Longitude   0.11455514438305599
# Pickup Centroid Location                   None
# Dropoff Centroid Latitude   0.05843544231278496
# Dropoff Centroid Longitude  0.07200598932628444
# Dropoff Centroid  Location                 None
#
#                                                                             3  \
# summary                                                                   min
# Trip ID                              0000006aa752d456d05c6eeb43b057adb1ffa540
# Taxi ID                     000daaa11a2d961100513e232a1ce05391c5d797d2dc56...
# Trip Start Timestamp                                   01/01/2024 01:00:00 AM
# Trip End Timestamp                                     01/01/2024 01:00:00 AM
# Trip Seconds                                                                0
# Trip Miles                                                                0.0
# Pickup Census Tract                                               17031010100
# Dropoff Census Tract                                              17031010100
# Pickup Community Area                                                       1
# Dropoff Community Area                                                      1
# Fare                                                                      0.0
# Tips                                                                      0.0
# Tolls                                                                     0.0
# Extras                                                                    0.0
# Trip Total                                                                0.0
# Payment Type                                                             Cash
# Company                                               2733 - 74600 Benny Jona
# Pickup Centroid Latitude                                         41.650221676
# Pickup Centroid Longitude                                       -87.913624596
# Pickup Centroid Location                 POINT (-87.5307124836 41.7030053028)
# Dropoff Centroid Latitude                                        41.650221676
# Dropoff Centroid Longitude                                      -87.913624596
# Dropoff Centroid  Location                POINT (-87.5349029012 41.707311449)
#
#                                         4              5              6  \
# summary                               25%            50%            75%
# Trip ID                          Infinity       Infinity       Infinity
# Taxi ID                              None           None           None
# Trip Start Timestamp                 None           None           None
# Trip End Timestamp                   None           None           None
# Trip Seconds                          480            943           1714
# Trip Miles                           1.03           3.34          11.98
# Pickup Census Tract           17031081700    17031320400    17031980000
# Dropoff Census Tract          17031081500    17031320100    17031839100
# Pickup Community Area                   8             32             63
# Dropoff Community Area                  8             28             32
# Fare                                  8.5           16.0           34.5
# Tips                                  0.0           0.57            4.0
# Tolls                                 0.0            0.0            0.0
# Extras                                0.0            0.0           2.25
# Trip Total                          10.25          19.22          43.22
# Payment Type                         None           None           None
# Company                              None           None           None
# Pickup Centroid Latitude     41.878865584    41.89503345    41.97907082
# Pickup Centroid Longitude   -87.750934289  -87.642648998  -87.625192142
# Pickup Centroid Location             None           None           None
# Dropoff Centroid Latitude    41.878865584   41.892042136   41.922686284
# Dropoff Centroid Longitude   -87.66351755  -87.633308037  -87.625192142
# Dropoff Centroid  Location           None           None           None
#
#                                                                             7
# summary                                                                   max
# Trip ID                              ffffffdda8f2f9f98cf474cce05b7e5e34dc25e4
# Taxi ID                     ffda53354c610fd3af1aee46d723028a49014e35f7280c...
# Trip Start Timestamp                                   12/31/2024 12:45:00 PM
# Trip End Timestamp                                     12/31/2024 12:45:00 PM
# Trip Seconds                                                            86396
# Trip Miles                                                             3397.8
# Pickup Census Tract                                               17031980100
# Dropoff Census Tract                                              17031980100
# Pickup Community Area                                                      77
# Dropoff Community Area                                                     77
# Fare                                                                  9999.75
# Tips                                                                    400.0
# Tolls                                                                  5550.0
# Extras                                                                 5559.5
# Trip Total                                                            9999.75
# Payment Type                                                          Unknown
# Company                                                           Wolley Taxi
# Pickup Centroid Latitude                                         42.021223593
# Pickup Centroid Longitude                                       -87.530712484
# Pickup Centroid Location                  POINT (-87.913624596 41.9802643146)
# Dropoff Centroid Latitude                                        42.021223593
# Dropoff Centroid Longitude                                      -87.534902901
# Dropoff Centroid  Location                POINT (-87.913624596 41.9802643146)

# %%
# General statistics
dftaxytrips.describe().toPandas().T
# Out:
#                                   0                      1  \
# summary                       count                   mean
# Trip ID                     7917844               Infinity
# Taxi ID                     7917844                   None
# Trip Start Timestamp        7917844                   None
# Trip End Timestamp          7917778                   None
# Trip Seconds                7916303     1254.9250153764958
# Trip Miles                  7917775      6.802327488467674
# Pickup Census Tract         3392900  1.7031508395342648E10
# Dropoff Census Tract        3281682   1.703141394138261E10
# Pickup Community Area       7691067      36.09328575605959
# Dropoff Community Area      7174891     26.293705646538744
# Fare                        7897269      22.89300292290886
# Tips                        7897269     2.9030046741474513
# Tolls                       7897269   0.029434495646532992
# Extras                      7897269     2.1529685008830275
# Trip Total                  7897269     28.182303074643663
# Payment Type                7917844                   None
# Company                     7917844                   None
# Pickup Centroid Latitude    7695376     41.901399650735996
# Pickup Centroid Longitude   7695376      -87.7019076253514
# Pickup Centroid Location    7695376                   None
# Dropoff Centroid Latitude   7220191       41.8921376218955
# Dropoff Centroid Longitude  7220191     -87.66080016228891
# Dropoff Centroid  Location  7220191                   None
#
#                                               2  \
# summary                                  stddev
# Trip ID                                    None
# Taxi ID                                    None
# Trip Start Timestamp                       None
# Trip End Timestamp                         None
# Trip Seconds                 1648.0977197601726
# Trip Miles                    7.957195844290252
# Pickup Census Tract           374237.3662004645
# Dropoff Census Tract          342509.8545557547
# Pickup Community Area        26.291497670579886
# Dropoff Community Area        20.81465342793271
# Fare                           33.2323786885119
# Tips                          4.284313925861233
# Tolls                        5.0707919401752175
# Extras                       10.395597618506331
# Trip Total                    38.30632012119162
# Payment Type                               None
# Company                                    None
# Pickup Centroid Latitude    0.06525246745369662
# Pickup Centroid Longitude   0.11455514438305599
# Pickup Centroid Location                   None
# Dropoff Centroid Latitude   0.05843544231278496
# Dropoff Centroid Longitude  0.07200598932628444
# Dropoff Centroid  Location                 None
#
#                                                                             3  \
# summary                                                                   min
# Trip ID                              0000006aa752d456d05c6eeb43b057adb1ffa540
# Taxi ID                     000daaa11a2d961100513e232a1ce05391c5d797d2dc56...
# Trip Start Timestamp                                   01/01/2024 01:00:00 AM
# Trip End Timestamp                                     01/01/2024 01:00:00 AM
# Trip Seconds                                                                0
# Trip Miles                                                                0.0
# Pickup Census Tract                                               17031010100
# Dropoff Census Tract                                              17031010100
# Pickup Community Area                                                       1
# Dropoff Community Area                                                      1
# Fare                                                                      0.0
# Tips                                                                      0.0
# Tolls                                                                     0.0
# Extras                                                                    0.0
# Trip Total                                                                0.0
# Payment Type                                                             Cash
# Company                                               2733 - 74600 Benny Jona
# Pickup Centroid Latitude                                         41.650221676
# Pickup Centroid Longitude                                       -87.913624596
# Pickup Centroid Location                 POINT (-87.5307124836 41.7030053028)
# Dropoff Centroid Latitude                                        41.650221676
# Dropoff Centroid Longitude                                      -87.913624596
# Dropoff Centroid  Location                POINT (-87.5349029012 41.707311449)
#
#                                                                             4
# summary                                                                   max
# Trip ID                              ffffffdda8f2f9f98cf474cce05b7e5e34dc25e4
# Taxi ID                     ffda53354c610fd3af1aee46d723028a49014e35f7280c...
# Trip Start Timestamp                                   12/31/2024 12:45:00 PM
# Trip End Timestamp                                     12/31/2024 12:45:00 PM
# Trip Seconds                                                            86396
# Trip Miles                                                             3397.8
# Pickup Census Tract                                               17031980100
# Dropoff Census Tract                                              17031980100
# Pickup Community Area                                                      77
# Dropoff Community Area                                                     77
# Fare                                                                  9999.75
# Tips                                                                    400.0
# Tolls                                                                  5550.0
# Extras                                                                 5559.5
# Trip Total                                                            9999.75
# Payment Type                                                          Unknown
# Company                                                           Wolley Taxi
# Pickup Centroid Latitude                                         42.021223593
# Pickup Centroid Longitude                                       -87.530712484
# Pickup Centroid Location                  POINT (-87.913624596 41.9802643146)
# Dropoff Centroid Latitude                                        42.021223593
# Dropoff Centroid Longitude                                      -87.534902901
# Dropoff Centroid  Location                POINT (-87.913624596 41.9802643146)

# %%
# Analysis of missing values in 'dftaxytrips'
missing_taxytrips = dftaxytrips.select([
    count(when(col(c).isNull() | isnan(c), c)).alias(c) # count (when (col (c) .isnull (), c)). aka (c)
    for c in dftaxytrips.columns
])

print("Missing values in Chicago Taxi Trips Dataset (CSV):")
missing_taxytrips.toPandas()
# Out:
# Missing values in Chicago Taxi Trips Dataset (CSV):
#    Trip ID  Taxi ID  Trip Start Timestamp  Trip End Timestamp  Trip Seconds  \
# 0        0        0                     0                  66          1541
#
#    Trip Miles  Pickup Census Tract  Dropoff Census Tract  \
# 0          69              4524944               4636162
#
#    Pickup Community Area  Dropoff Community Area  ...  Extras  Trip Total  \
# 0                 226777                  742953  ...   20575       20575
#
#    Payment Type  Company  Pickup Centroid Latitude  Pickup Centroid Longitude  \
# 0             0        0                    222468                     222468
#
#    Pickup Centroid Location  Dropoff Centroid Latitude  \
# 0                    222468                     697653
#
#    Dropoff Centroid Longitude  Dropoff Centroid  Location
# 0                      697653                      697653
#
# [1 rows x 23 columns]

# %%
# Function to eliminate atypical values of a dataframe and modify it
def remove_outliers_inplace(df, column):
    # Calculate the Q1 and Q3 percentiles for the column
    percentiles = df.approxQuantile(column, [0.25, 0.75], 0.05)  # 5% calculation error
    Q1 = percentiles[0]
    Q3 = percentiles[1]

    # Calculate the IQR
    IQR = Q3 - Q1

    # Define the lower and upper limits for atypical values
    lower_limit = Q1 - 1.5 * IQR
    upper_limit = Q3 + 1.5 * IQR

    # Filter the dataframe to eliminate atypical values and modify the original data
    df = df.filter((col(column) >= lower_limit) & (col(column) <= upper_limit))

    return df

# %%
# List of numerical columns
columns_to_plot = ["Trip Seconds", "Trip Miles", "Fare", "Tips", "Tolls", "Extras", "Trip Total"]

# Eliminate atypical values in each column and update the original dataframe
for column in columns_to_plot:
    dftaxytrips = remove_outliers_inplace(dftaxytrips, column)

# %%
# Graph histograms directly
plt.figure(figsize=(12, 10))
for i, column in enumerate(columns_to_plot, 1):
    # Obtain column data after eliminating atypical values
    data = dftaxytrips.select(column).dropna().toPandas()

    # Graph the histogram
    plt.subplot(3, 3, i)
    plt.hist(data, bins=30, edgecolor='black')
    plt.title(f"{column} Histogram")
    plt.xlabel(column)
    plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
# Graph the boxplots directly
plt.figure(figsize=(12, 10))
for i, column in enumerate(columns_to_plot, 1):
    # Obtain column data
    data = dftaxytrips.select(column).dropna().toPandas()

    # Graph the boxploot
    plt.subplot(3, 3, i)
    sns.boxplot(x=data[column])
    plt.title(f"Boxplot of {column}")
    plt.xlabel(column)

plt.tight_layout()
plt.show()

# %%
# List of non -numerical columns
non_numeric_columns = ["Trip Start Timestamp", "Trip End Timestamp", "Payment Type", "Company",
                       "Pickup Centroid Location", "Dropoff Centroid  Location"]

# %%
# Visualization of non -numerical columns values
plt.figure(figsize=(12, 10))

for i, column in enumerate(non_numeric_columns, 1):
    plt.subplot(3, 3, i)
    # Count the frequencies of each category
    df_filtered = dftaxytrips.select(column).dropna()  # Eliminate null values
    value_counts = df_filtered.groupBy(column).count().toPandas()

    # Bars chart for each column
    sns.barplot(x=column, y="count", data=value_counts)
    plt.title(f"Frequency of {column}")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.xticks([])
plt.tight_layout()
plt.show()

# %%
# Check the amount of null values in non -numerical columns
print("\n Quantity of null values in non-numerical columns:")
for column in non_numeric_columns:
    null_count = dftaxytrips.filter(col(column).isNull()).count()
    print(f"{column}: {null_count} null values")
# Out:
#  Quantity of null values in non-numerical columns:
# Trip Start Timestamp: 0 null values
# Trip End Timestamp: 0 null values
# Payment Type: 0 null values
# Company: 0 null values
# Pickup Centroid Location: 123623 null values
# Dropoff Centroid  Location: 203356 null values
